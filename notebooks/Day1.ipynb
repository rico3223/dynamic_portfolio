# %%
from yahooquery import Ticker

from yahooquery import Screener

import pandas as pd

import backtrader as bt

import requests

# %%
url_1 = 'https://www.alphavantage.co/query?function=CPI&interval=monthly&apikey=1SYRQ11PMC5JRDTU&datatype=csv'
cpi = pd.read_csv(url_1)
cpi
# Out:
#        timestamp    value
# 0     2022-10-01  298.012
# 1     2022-09-01  296.808
# 2     2022-08-01  296.171
# 3     2022-07-01  296.276
# 4     2022-06-01  296.311
# ...          ...      ...
# 1313  1913-05-01    9.700
# 1314  1913-04-01    9.800
# 1315  1913-03-01    9.800
# 1316  1913-02-01    9.800
# 1317  1913-01-01    9.800
#
# [1318 rows x 2 columns]

# %%
cpi_levels = cpi[['value']].round(2)
cpi['CPI'] = cpi_levels
cpi
# Out:
#        timestamp    value     CPI
# 0     2022-10-01  298.012  298.01
# 1     2022-09-01  296.808  296.81
# 2     2022-08-01  296.171  296.17
# 3     2022-07-01  296.276  296.28
# 4     2022-06-01  296.311  296.31
# ...          ...      ...     ...
# 1313  1913-05-01    9.700    9.70
# 1314  1913-04-01    9.800    9.80
# 1315  1913-03-01    9.800    9.80
# 1316  1913-02-01    9.800    9.80
# 1317  1913-01-01    9.800    9.80
#
# [1318 rows x 3 columns]

# %%
url_2 = 'https://www.alphavantage.co/query?function=INFLATION&apikey=1SYRQ11PMC5JRDTU&datatype=csv'
inflation = pd.read_csv(url_2)
inflation
# Out:
#      timestamp     value
# 0   2021-01-01  4.697859
# 1   2020-01-01  1.233584
# 2   2019-01-01  1.812210
# 3   2018-01-01  2.442583
# 4   2017-01-01  2.130110
# ..         ...       ...
# 57  1964-01-01  1.278912
# 58  1963-01-01  1.239669
# 59  1962-01-01  1.198773
# 60  1961-01-01  1.070724
# 61  1960-01-01  1.457976
#
# [62 rows x 2 columns]

# %%
inflation_levels = inflation[['value']].round(2)
inflation['Inflation (%)'] = inflation_levels
inflation
# Out:
#      timestamp     value  Inflation (%)  Inflation Expectation (%)
# 0   2021-01-01  4.697859           4.70                        5.0
# 1   2020-01-01  1.233584           1.23                        4.7
# 2   2019-01-01  1.812210           1.81                        4.8
# 3   2018-01-01  2.442583           2.44                        5.2
# 4   2017-01-01  2.130110           2.13                        5.3
# ..         ...       ...            ...                        ...
# 57  1964-01-01  1.278912           1.28                        2.7
# 58  1963-01-01  1.239669           1.24                        2.7
# 59  1962-01-01  1.198773           1.20                        2.5
# 60  1961-01-01  1.070724           1.07                        2.4
# 61  1960-01-01  1.457976           1.46                        2.7
#
# [62 rows x 4 columns]

# %%
url_3 = 'https://www.alphavantage.co/query?function=INFLATION_EXPECTATION&apikey=1SYRQ11PMC5JRDTU&datatype=csv'
inflation_expectation = pd.read_csv(url_3)
inflation_expectation
# Out:
#       timestamp  value
# 0    2022-10-01    5.0
# 1    2022-09-01    4.7
# 2    2022-08-01    4.8
# 3    2022-07-01    5.2
# 4    2022-06-01    5.3
# ..          ...    ...
# 533  1978-05-01    6.9
# 534  1978-04-01    6.7
# 535  1978-03-01    6.3
# 536  1978-02-01    6.4
# 537  1978-01-01    5.2
#
# [538 rows x 2 columns]

# %%
url_4 = 'https://www.alphavantage.co/query?function=UNEMPLOYMENT&apikey=1SYRQ11PMC5JRDTU&datatype=csv'
unemployment = pd.read_csv(url_4)
unemployment
# Out:
#       timestamp  value
# 0    2022-10-01    3.7
# 1    2022-09-01    3.5
# 2    2022-08-01    3.7
# 3    2022-07-01    3.5
# 4    2022-06-01    3.6
# ..          ...    ...
# 893  1948-05-01    3.5
# 894  1948-04-01    3.9
# 895  1948-03-01    4.0
# 896  1948-02-01    3.8
# 897  1948-01-01    3.4
#
# [898 rows x 2 columns]

# %%
url_5 = 'https://www.alphavantage.co/query?function=NONFARM_PAYROLL&apikey=1SYRQ11PMC5JRDTU&datatype=csv'
nonfarm_payroll = pd.read_csv(url_5)
nonfarm_payroll
# Out:
#        timestamp   value
# 0     2022-10-01  154369
# 1     2022-09-01  153197
# 2     2022-08-01  152674
# 3     2022-07-01  152258
# 4     2022-06-01  152607
# ...          ...     ...
# 1001  1939-05-01   30145
# 1002  1939-04-01   29786
# 1003  1939-03-01   29804
# 1004  1939-02-01   29394
# 1005  1939-01-01   29296
#
# [1006 rows x 2 columns]

# %%
url_6 = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&topics=technology&apikey=1SYRQ11PMC5JRDTU&datatype=json'

r = requests.get(url_6)
data = r.json()['feed']

sentiment = pd.DataFrame(data)
sentiment
# Out:
#                                                 title  \
# 0                           2 FAANG Stocks to Buy Now
# 1   China Protests Vs. Covid Policy Rock Markets; ...
# 2   Apple's Extreme Dependence on China Can No Lon...
# 3   Analyst Says Coinbase 'A Waste Of Time', Taylo...
# 4   6M Shortfall In Apple iPhone Pro Models - Chin...
# 5         Futures Fall As China Covid Protests Spread
# 6   Apple Could Face 10% Hit to iPhone Output on F...
# 7                         3 Stocks to Avoid This Week
# 8   Buying This Manchester United Call Option On T...
# 9   Stocks making the biggest moves in the premark...
# 10  How Protests Against Xi Jinping Are Sending Ap...
# 11  US Stocks: Wall Street futures slip on China C...
# 12  Many investors are betting on an inflation pea...
# 13     Will the Nasdaq or S&P 500 Have a Better 2023?
# 14  Wall St futures slip on China COVID woes; Appl...
# 15  Cyber Monday Bonanza: Grab A 2020 MacBook Air ...
# 16  Xi Jinping Faces Protests, Doge Tops 10 Cents,...
# 17  Should Invesco FTSE RAFI US 1000 ETF  ( PRF ) ...
# 18                Down 17%, Is Apple Stock a Buy Now?
# 19  Nasdaq, S&P 500 Futures See Rough Start To Wee...
# 20  Apple Stock Slides On Report of 6 Million Hit ...
# 21  Wearable Technology Market to Hit $186.14 Bill...
# 22  Stocks Move Lower, Week Ahead, Apple, Fox And ...
# 23  U.S. stock futures slide as China unrest raise...
# 24  Since 2016, Warren Buffett Has Bought $9 Billi...
# 25  China's zero COVID strategy 'doesn't make publ...
# 26  Apple will produce 6 million fewer iPhone pros...
# 27  Nasdaq Settles Lower, Market Volatility Rises ...
# 28  Apple China Supplier Offers $1,800 Bonus To Wo...
# 29  Augmented Reality and Virtual Reality Market S...
# 30  Tesla, Amazon, Apple, Lufax And SoFi: Why Thes...
# 31  Apple Co-Founder Says Many Cryptocurrencies Ar...
# 32  Shanghai Hit By COVID Protests: Demonstrators ...
# 33  A $1,000 Investment In Apple Just After Thanks...
# 34  Steve Jobs Told Zynga In-App Purchases Were 'S...
# 40  [{'topic': 'Technology', 'relevance_score': '0...
# 41  [{'topic': 'Technology', 'relevance_score': '0...
# 42  [{'topic': 'Finance', 'relevance_score': '0.25...
# 43  [{'topic': 'Technology', 'relevance_score': '1...
# 44  [{'topic': 'Technology', 'relevance_score': '0...
# 45  [{'topic': 'Financial Markets', 'relevance_sco...
# 46  [{'topic': 'Life Sciences', 'relevance_score':...
# 47  [{'topic': 'Finance', 'relevance_score': '0.25...
# 48  [{'topic': 'Technology', 'relevance_score': '1...
# 49  [{'topic': 'Life Sciences', 'relevance_score':...
#
#     overall_sentiment_score overall_sentiment_label  \
# 0                  0.196016        Somewhat-Bullish
# 1                 -0.155324        Somewhat-Bearish
# 2                 -0.021871                 Neutral
# 3                 -0.058090                 Neutral
# 4                 -0.205802        Somewhat-Bearish
# 5                  0.033773                 Neutral
# 6                 -0.130780                 Neutral
# 7                 -0.012190                 Neutral
# 8                  0.084215                 Neutral
# 9                 -0.049863                 Neutral
# 10                -0.021607                 Neutral
# 11                -0.191023        Somewhat-Bearish
# 12                -0.069826                 Neutral
# 13                 0.216767        Somewhat-Bullish
# 14                -0.199649        Somewhat-Bearish
# 15                 0.103004                 Neutral
# 16                -0.050642                 Neutral
# 17                 0.220114        Somewhat-Bullish
# 18                 0.325580        Somewhat-Bullish
# 19                -0.122787                 Neutral
# 20                 0.017225                 Neutral
# 21                 0.357604                 Bullish
# 22                -0.138993                 Neutral
# 23                -0.204172        Somewhat-Bearish
# 24                 0.277896        Somewhat-Bullish
# 25                -0.173056        Somewhat-Bearish
# 26                -0.212489        Somewhat-Bearish
# 27                -0.045718                 Neutral
# 28                 0.077515                 Neutral
# 29                 0.284560        Somewhat-Bullish
# 30                -0.081819                 Neutral
# 31                 0.115644                 Neutral
# 32                -0.202934        Somewhat-Bearish
# 33                 0.173613        Somewhat-Bullish
# 34                 0.275707        Somewhat-Bullish
# 35                 0.221841        Somewhat-Bullish
# 36                 0.167810        Somewhat-Bullish
# 37                 0.209787        Somewhat-Bullish
# 38                 0.004814                 Neutral
# 39                 0.222476        Somewhat-Bullish
# 40                 0.136393                 Neutral
# 41                -0.082657                 Neutral
# 42                 0.102413                 Neutral
# 43                 0.111064                 Neutral
# 44                 0.110028                 Neutral
# 45                 0.102613                 Neutral
# 46                 0.095523                 Neutral
# 47                 0.286792        Somewhat-Bullish
# 48                 0.065008                 Neutral
# 49                 0.095522                 Neutral
#
#                                      ticker_sentiment
# 0   [{'ticker': 'AMZN', 'relevance_score': '0.3778...
# 1   [{'ticker': 'TSLA', 'relevance_score': '0.1291...
# 2   [{'ticker': 'JPM', 'relevance_score': '0.06194...
# 3   [{'ticker': 'AZN', 'relevance_score': '0.10912...
# 4   [{'ticker': 'MS', 'relevance_score': '0.135347...
# 5   [{'ticker': 'TSLA', 'relevance_score': '0.1699...
# 6   [{'ticker': 'AAPL', 'relevance_score': '0.9813...
# 7   [{'ticker': 'LKNCY', 'relevance_score': '0.066...
# 8   [{'ticker': 'MANU', 'relevance_score': '0.7246...
# 9   [{'ticker': 'CVX', 'relevance_score': '0.25653...
# 10  [{'ticker': 'TSLA', 'relevance_score': '0.6154...
# 7    AAPL        0.129376              -0.171661       Somewhat-Bearish
# 8    DXCM        0.051943                    0.0                Neutral
# 9      DG        0.129376              -0.028199                Neutral
# 10   PSTG        0.180364               0.024231                Neutral
# 11   NVDA        0.103666               0.016631                Neutral
# 12   MSFT        0.129376               0.003651                Neutral
# 13    CAR        0.051943                    0.0                Neutral
# 14    PDD        0.154951               0.108985                Neutral

# %%
components_sp500 = pd.read_csv('/Users/ArthurAllonsius/Desktop/Projet Wagon/List Stocks S&P500/constituents_csv.csv')
components_sp500 = components_sp500.drop(columns = 'Name')
components_sp500 = components_sp500.drop(columns = 'Sector')

# %%
components_sp500
# Out:
#     Symbol
# 0      MMM
# 1      AOS
# 2      ABT
# 3     ABBV
# 4     ABMD
# ..     ...
# 500    YUM
# 501   ZBRA
# 502    ZBH
# 503   ZION
# 504    ZTS
#
# [505 rows x 1 columns]

# %%
class BacktestBase(object):

def __init__ (self, symbol, start, end, amount, ftc=0.0, ptc=0.0, verbose=True):
    
       self.symbol = symbol
       self.start = start
       self.end = end
       self.initial_amount = amount
       self.amount = amount
       self.ftc = ftc
       self.ptc = ptc
       self.units = 0
       self.position = 0
       self.trades = 0
       self.verbose = verbose
       self.get_data()

def get_data(self):
    
    raw = pd.read_csv('http://hilpisch.com/pyalgo_eikon_eod_data.csv', index_col = 0, parse_dates = True).dropna()
    raw = pd.DataFrame(raw[self.symbol])
    raw = raw.loc[self.start:self.end]
    raw.rename(columns={self.symbol: 'price'}, inplace = True)
    raw['return'] = np.log(raw / raw.shift(1))
    self.data = raw.dropna()
    
def plot_data(self, cols=None):
    
    if cols is None:
        cols = ['price']
    self.data['price'].plot(figsize=(10,6), title=self.symbol)
    
def get_data_price(self, bar):
    
    date = str(self.data.index[bar])[:10]
    price = self.data.price.iloc[bar]
    return date, price

def print_balance(self, bar):
    
    date, price = self.get_date_price(bar)
    print(f'{date} | current balance {self.amount:2f}')
    
def print_net_wealth(self, bar):
    
    date, price = self.get_date_price(bar)
    net_wealth = self.units * price + self.amount
    print(f'{date} | current net wealth {net_wealth:2f}')

def place_buy_order(self, bar, units = None, amount = None):
    
    date, price = self.get_data_price(bar)
    if units is None:
        units = int(amount / price)
    self.amount -= (units * price) * (1 + self.ptc) + self.ftc
    self.units += units
    self.trades += 1
    if self.verbose:
        print(f'{date} | selling {units} units at {price:.2f}')
        self.print_balance(bar)
        self.print_net_wealth(bar)

def place_sell_order(self, bar, units = None, amount = None):
   
    date, price = self.get_data_price(bar)
    if units is None:
        units = int(amount / price)
    self.amount += (units * price) * (1 - self.ptc) - self.ftc
    self.units -= units
    self.trades += 1
    if self.verbose:
        print(f'{date} | selling {units} units at {price:.2f}')
        self.print_balance(bar)
        self.print_net_wealth(bar)
        
def close_out(self, bar):
    date, price = self.get_data_price(bar)
    self.amount += self.units * price 
    self.units = 0
    self.trades += 1
    if self.verbose:
        print(f'{date} | inventory {self.units} units at {price:.2f}')
        print('=' * 55)
    print('Final balance [$] {:.2f}'.format(self.amount))
    perf = ((self.amount - self.initial_amount) / self.initial_amount * 100)
    print('Net Performance [%] {:.2f}'.format(perf))
    print('Trades Executed [#] {:.2f}'.format(self.trades))
    print('=' * 55)
    
if __name__ == '__main__':
    bb = BacktestBase('SPY', '2010-01-04', '2019-12-31', 10000)
    print(bb.data.info())
    print(bb.data.tail())
    bb.plot_data()
# Out:
#   Cell In [1], line 3
#     def __init__ (self, symbol, start, end, amount, ftc=0.0, ptc=0.0, verbose=True):
#     ^
# IndentationError: expected an indented block after class definition on line 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
raw = pd.read_csv('http://hilpisch.com/pyalgo_eikon_eod_data.csv', index_col = 0, parse_dates = True).dropna()
raw = pd.DataFrame(raw['SPY'])
raw = raw.loc['2010-01-04':'2019-12-31']
# raw.rename(columns={self.symbol: 'price'}, inplace = True)
raw['return'] = np.log(raw / raw.shift(1))
raw['return'] = raw['return'].dropna()
raw['return'][1:].head(15)
# Out:
# Date
# 2010-01-05    0.002644
# 2010-01-06    0.000704
# 2010-01-07    0.004212
# 2010-01-08    0.003322
# 2010-01-11    0.001396
# 2010-01-12   -0.009370
# 2010-01-13    0.008411
# 2010-01-14    0.002701
# 2010-01-15   -0.011288
# 2010-01-19    0.012418
# 2010-01-20   -0.010221
# 2010-01-21   -0.019416
# 2010-01-22   -0.022544
# 2010-01-25    0.005115
# 2010-01-26   -0.004199
# Name: return, dtype: float64

# %%
def max_drawdown_sequence(return_col):
    return_col = return_col[1:]
    final = 0 
    temp_counter = 0 
    index_drawdown_final = []
    index_drawdown_temp = []
    counter = 0
    for k in return_col:
        counter += 1 
        if k < 0:
            temp_counter += 1
            index_drawdown_temp.append(counter)
            if temp_counter > final:
                final = temp_counter
                index_drawdown_final = index_drawdown_temp
        else:
            temp_counter = 0 
            index_drawdown_temp = []

    return final, index_drawdown_final

# %%
def max_drawdown_absolute(length_interval, return_col):
    return_col = return_col[1:]
    max_drawdown = 0
    index_drawdown_final = []
    index_drawdown_temp = []
    counter = 0
    
    for k in range(0, return_col.shape[0]-length_interval):
        counter += 1
        temp_df = return_col[k: k+length_interval]
        sum_return = np.sum(temp_df)
        index_drawdown_temp = list(range(k, k+length_interval))
        if sum_return < max_drawdown: 
            max_drawdown = sum_return
            index_drawdown_final = index_drawdown_temp
            counter = 0
            
    return max_drawdown, index_drawdown_final

# %%
max_drawdown_absolute(100, raw['return'])
# Out:
# (-0.20127420326613216,
#  [341,
#   342,
#   343,
#   344,
#   345,
#   346,
#   347,
#   348,
#   349,
#   350,
#   351,
#   352,
#   353,
#   354,
#   355,
#   356,
#   357,
#   358,
#   359,
#   360,
#   361,
#   362,
#   363,
#   364,
#   365,
#   366,
#   367,
#   368,
#   369,
#   370,
#   371,
#   372,
#   373,
#   374,
#   375,
#   376,
#   377,
#   378,
#   379,
#   380,
#   381,
#   382,
#   383,
#   384,
#   385,
#   386,
#   387,
#   388,
#   389,
#   390,
#   391,
#   392,
#   393,
#   394,
#   395,
#   396,
#   397,
#   398,
#   399,
#   400,
#   401,
#   402,
#   403,
#   404,
#   405,
#   406,
#   407,
#   408,
#   409,
#   410,
#   411,
#   412,
#   413,
#   414,
#   415,
#   416,
#   417,
#   418,
#   419,
#   420,
#   421,
#   422,
#   423,
#   424,
#   425,
#   426,
#   427,
#   428,
#   429,
#   430,
#   431,
#   432,
#   433,
#   434,
#   435,
#   436,
#   437,
#   438,
#   439,
#   440])

# %%
raw['return']
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05    0.002644
# 2010-01-06    0.000704
# 2010-01-07    0.004212
# 2010-01-08    0.003322
#                 ...
# 2019-12-24    0.000031
# 2019-12-26    0.005309
# 2019-12-27   -0.000248
# 2019-12-30   -0.005528
# 2019-12-31    0.002426
# Name: return, Length: 2516, dtype: float64

# %%
max_drawdown(raw['return'])
# Out:
# (8, [2252, 2253, 2254, 2255, 2256, 2257, 2258, 2259])

# %%
raw['return'][2252]
raw['return'][2253]
raw['return'][2254]
raw['return'][2255]
raw['return'][2256]
raw['return'][2257]
raw['return'][2258]
raw['return'][2259]
# Out:
# -0.02677829254901674

# %%
raw['return'].index[1]
# Out:
# Timestamp('2010-01-05 00:00:00')

# %%
plt.plot(raw['return'])

# %%
plt.plot(raw['price'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.6/envs/dynamic_portfolio/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/.pyenv/versions/3.10.6/envs/dynamic_portfolio/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.pyenv/versions/3.10.6/envs/dynamic_portfolio/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 plt.plot(raw['price'])
#
# File ~/.pyenv/versions/3.10.6/envs/dynamic_portfolio/lib/python3.10/site-packages/pandas/core/frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File ~/.pyenv/versions/3.10.6/envs/dynamic_portfolio/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'price'
